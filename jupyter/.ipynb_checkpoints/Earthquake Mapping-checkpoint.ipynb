# %%
import pandas
import urllib.request
import json
import folium

# %%
#all earthquakes from the past hour:
url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_hour.geojson"

#all earthquakes from the past day:
#url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.geojson"

#to eliminate the certificate error, run the "install Certificates.command" from the python folder
#or see https://stackoverflow.com/questions/35569042/python-3-ssl-certificate-verify-failed

#open and close connection to url and read html
with urllib.request.urlopen(url) as response:
    html = response.read()
    print(response.getcode())
# Out:
# 200

# %%
#load data form geoJson
#throw data into a list object (is this neesesary?)
data = json.loads(html)
#for i in data["features"]: print( i["properties"]["place"])
quakes = []
mags = []
#make a list of locations from the json data
for i in data["features"]: 
    quakes.append(i["geometry"]["coordinates"])
#make a list of magnitues from the json data    
for i in data["features"]:
    mags.append(i["properties"]["mag"])

#throw earthquake locations in a pandas dataframe
df_quakes = pandas.DataFrame(quakes)

#rename the ugly columns. (i don't know what that third attribute is...)
df_quakes.columns =['lon','lat','depth']

#append magnitude list to the quakes data frame
df_quakes["mag"]=mags

#proportional symbol range: 100-200
df_quakes['symbol_size'] = df_quakes.mag.apply(lambda x: x*5)


def opacityNormalizer(depth):
    depth_range = df_quakes['depth'].max()-df_quakes['depth'].min()
    opacity = 1-(depth/depth_range*.66)
    return opacity




df_quakes
# Out:
#             lon        lat    depth   mag  symbol_size
# 0   -149.937200  62.121400   48.900  1.80         9.00
# 1   -117.641800  37.809500    1.400  1.40         7.00
# 2   -118.632000  38.586500    3.500  1.90         9.50
# 3   -122.820000  38.807335    1.930  0.78         3.90
# 4   -112.530500  46.867167   12.620  1.25         6.25
# 5   -116.602333  33.449833   11.390  0.69         3.45
# 6   -116.800167  33.502000    4.530  0.53         2.65
# 7   -118.802666  37.457501   -0.650  2.39        11.95
# 8   -116.281500  35.633833    6.150  1.61         8.05
# 9   -118.878502  37.648334    4.190  0.84         4.20
# 10  -116.314167  34.014500    2.750  1.04         5.20
# 11  -150.009900  66.233200    1.800  1.60         8.00
# 12  -117.543667  35.974500    4.930  0.30         1.50
# 13  -122.714333  38.782501    2.020  1.28         6.40
# 14  -116.792333  33.511167    6.230  0.52         2.60
# 15  -117.019833  33.876000   -0.600  1.20         6.00
# 16  -153.244100  60.167900  148.900  2.80        14.00
# 17   141.196900  37.099700   47.420  5.40        27.00
# 18  -156.519000  67.566300    0.000  1.70         8.50
# 19  -115.894167  31.614000    5.890  2.60        13.00
# 20  -152.192500  59.803700   20.000  1.60         8.00
# 21  -119.925800  39.424800   12.500  0.90         4.50
# 22  -118.476667  35.752167    2.240  1.40         7.00
# 23  -118.939000  38.405600    0.000  2.10        10.50
# 24    95.097700  12.003900   21.820  5.10        25.50
# 25  -116.702833  33.631167   17.820  0.72         3.60
# 26  -150.445600  63.316700  112.000  2.00        10.00
# 27  -149.648500  60.902600   21.100  2.40        12.00
# 28  -122.776497  38.806168    0.530  1.80         9.00
# 29  -122.780167  38.809166    0.890  0.49         2.45
# ..          ...        ...      ...   ...          ...
# 152 -122.810167  38.820500    2.040  1.63         8.15
# 153 -127.192000  40.163167   11.620  3.14        15.70
# 154 -116.675833  33.633667   13.870  0.40         2.00
# 155 -155.289833  19.374000    1.772  1.02         5.10
# 156 -151.012600  65.874200    0.100  1.70         8.50
# 157 -122.654333  45.956167   10.310  0.77         3.85
# 158 -118.838167  37.513833   -0.270  0.70         3.50
# 159 -150.986500  65.909800    0.000  1.90         9.50
# 160 -118.837167  37.504167    0.070  1.29         6.45
# 161 -118.820833  37.605000    3.850  0.70         3.50
# 162 -116.292000  36.617800    6.200 -0.10        -0.50
# 163 -118.882667  37.548500    2.680  0.37         1.85
# 164 -117.491000  33.846167   -0.480  1.31         6.55
# 165 -118.846500  37.560833    7.700  0.13         0.65
# 166 -118.839333  37.606333    2.520  0.55         2.75
# 167 -117.138167  33.669500   -0.540  0.58         2.90
# 168 -118.817500  37.604333    4.020  0.94         4.70
# 169 -122.104833  37.324833   -0.310  1.41         7.05
# 170 -147.766300  63.520900   14.500  1.50         7.50
# 171 -117.805000  36.041667    1.810  0.04         0.20
# 172 -122.383500  40.709833   19.570  2.03        10.15
# 173 -112.119167  45.720167    4.870  0.72         3.60
# 174 -151.005100  65.873500    0.000  1.60         8.00
# 175 -122.194667  40.598333   15.650  1.48         7.40
# 176 -118.833833  37.493500    4.880  0.76         3.80
# 177 -149.393500  64.685100   28.000  0.90         4.50
# 178 -116.790667  33.510833    6.630  0.47         2.35
# 179 -116.072333  33.020667   -0.800  1.44         7.20
# 180 -150.785000  60.877400   34.800  2.40        12.00
# 181 -117.720667  36.004000    2.640  1.00         5.00
#
# [182 rows x 5 columns]

# %%
df_quakes.mean()
#calculate mean center
mean_lat = df_quakes.mean().lat
mean_lon = df_quakes.mean().lon

# %%
#center = 

#make a map!
m = folium.Map(location=[mean_lat,mean_lon],zoom_start=2.5)
#put some shit on the map!

#make a feature group
epicenters = folium.FeatureGroup(name="earthquakes")


#iterate over data and plot them all at once
#use zip to iterate through data and make circles in map
#add a proportional symbol functionality to earthquake symbols
for lat,lon, mag, symbol_size,depth in zip(df_quakes.lat, df_quakes.lon, df_quakes.mag, df_quakes.symbol_size,df_quakes.depth):
    folium.CircleMarker(
        radius=symbol_size,
        location=[lat, lon],
        popup= folium.Popup("Magnitude: "+str(mag)+", Depth: "+str(depth)+"km",parse_html=True),
        color='crimson',
        opacity = opacityNormalizer(depth),
        fill=False,
    ).add_to(epicenters)
#after adding the data to the 'epicenters' feature group, you have to add the features to the map
epicenters.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
